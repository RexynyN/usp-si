# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [2, 5, 10, 50, 100]

y1 = [
0.000116,
0.000118,
0.000131,
0.000120,
0.000127
]

z1 = [
0.036986,
0.045608,
0.029207,
0.013896,
0.016370,
]

y2 = [
0.000117,
0.000117,
0.000115,
0.000126,
0.000106,
]

z2 = [
0.011673,
0.012694,
0.022194,
0.073685,
0.023971,
]

y3 = [
0.000143,
0.000135,
0.000134,
0.000139,
0.000142,
]

z3 = [
0.028716,
0.008852,
0.011834,
0.013032,
0.013528,
]


y4 = [
0.000134,
0.000135,
0.000157,
0.000131,
0.000104,
]

z4 = [
0.015249,
0.013267,
0.016221,
0.014849,
0.013972,
]

 
figure, axis = plt.subplots(2, 2, figsize=(10, 8))

# For Sine Function
axis[0, 0].plot(x, y1, color='r', label='Normal')
axis[0, 0].plot(x, z1, color='g', label='Paralelizado')
axis[0, 0].set_title("KNN=3 PREV=2 SLIDE=3")

# For Cosine Function
axis[0, 1].plot(x, y2, color='r', label='Normal')
axis[0, 1].plot(x, z2, color='g', label='Paralelizado')
axis[0, 1].set_title("KNN=4 PREV=3 SLIDE=4")

# For Tangent Function
axis[1, 0].plot(x, y3, color='r', label='Normal')
axis[1, 0].plot(x, z3, color='g', label='Paralelizado')
axis[1, 0].set_title("KNN=5 PREV=4 SLIDE=5")

# For Tanh Function
axis[1, 1].plot(x, y4, color='r', label='Normal')
axis[1, 1].plot(x, z4, color='g', label='Paralelizado')
axis[1, 1].set_title("KNN=6 PREV=5 SLIDE=6")

figure.suptitle('Teste de 10 Observações')
# Out:
# Text(0.5, 0.98, 'Teste de 10 Observações')

# %%
x = [2, 5, 10, 50, 100]

y1 = [
0.000882,
0.001186,
0.001090,
0.001051,
0.001256,
]

z1 = [
0.020370,
0.013207,
0.013396,
0.014493,
0.012350,
]

y2 = [
0.001178,
0.001076,
0.001741,
0.001693,
0.001817,
]

z2 = [
0.024305,
0.012128,
0.013986,
0.015467,
0.015653,
]

y3 = [
0.001439,
0.001312,
0.001353,
0.001304,
0.001882,
]

z3 = [
0.015736,
0.017329,
0.013711,
0.011369,
0.019060,
]


y4 = [
0.002223,
0.001595,
0.001509,
0.001594,
0.001664,
]

z4 = [
0.013140,
0.011293,
0.016940,
0.051694,
0.012285,
]

 
figure, axis = plt.subplots(2, 2, figsize=(10, 8))

# For Sine Function
axis[0, 0].plot(x, y1, color='r', label='Normal')
axis[0, 0].plot(x, z1, color='g', label='Paralelizado')
axis[0, 0].set_title("KNN=3 PREV=2 SLIDE=3")

# For Cosine Function
axis[0, 1].plot(x, y2, color='r', label='Normal')
axis[0, 1].plot(x, z2, color='g', label='Paralelizado')
axis[0, 1].set_title("KNN=4 PREV=3 SLIDE=4")

# For Tangent Function
axis[1, 0].plot(x, y3, color='r', label='Normal')
axis[1, 0].plot(x, z3, color='g', label='Paralelizado')
axis[1, 0].set_title("KNN=5 PREV=4 SLIDE=5")

# For Tanh Function
axis[1, 1].plot(x, y4, color='r', label='Normal')
axis[1, 1].plot(x, z4, color='g', label='Paralelizado')
axis[1, 1].set_title("KNN=6 PREV=5 SLIDE=6")

figure.suptitle('Teste de 100 Observações')
# Out:
# Text(0.5, 0.98, 'Teste de 100 Observações')

# %%
x = [2, 5, 10, 50, 100]

y1 = [
0.009152,
0.009354,
0.009386,
0.009249,
0.009266,
]

z1 = [
0.034442,
0.029463,
0.015816,
0.010600,
0.014241,
]

y2 = [
0.012364,
0.011446,
0.012124,
0.012344,
0.013239,
]

z2 = [
0.022746,
0.027921,
0.009793,
0.018563,
0.020914,
]

y3 = [
0.015699,
0.015157,
0.013177,
0.015583,
0.014869,
]

z3 = [
0.020373,
0.051421,
0.017782,
0.021438,
0.018484,
]


y4 = [
0.018487,
0.016805,
0.018046,
0.017334,
0.020315,
]

z4 = [
0.023983,
0.019343,
0.019371,
0.015144,
0.017608,
]

 
figure, axis = plt.subplots(2, 2, figsize=(10, 8))

# For Sine Function
axis[0, 0].plot(x, y1, color='r', label='Normal')
axis[0, 0].plot(x, z1, color='g', label='Paralelizado')
axis[0, 0].set_title("KNN=3 PREV=2 SLIDE=3")

# For Cosine Function
axis[0, 1].plot(x, y2, color='r', label='Normal')
axis[0, 1].plot(x, z2, color='g', label='Paralelizado')
axis[0, 1].set_title("KNN=4 PREV=3 SLIDE=4")

# For Tangent Function
axis[1, 0].plot(x, y3, color='r', label='Normal')
axis[1, 0].plot(x, z3, color='g', label='Paralelizado')
axis[1, 0].set_title("KNN=5 PREV=4 SLIDE=5")

# For Tanh Function
axis[1, 1].plot(x, y4, color='r', label='Normal')
axis[1, 1].plot(x, z4, color='g', label='Paralelizado')
axis[1, 1].set_title("KNN=6 PREV=5 SLIDE=6")

figure.suptitle('Teste de 1.000 Observações')
# Out:
# Text(0.5, 0.98, 'Teste de 1.000 Observações')

# %%
x = [2, 5, 10, 50, 100]

y1 = [
0.911686,
0.911688,
0.911776,
0.914686,
0.911977,
]

z1 = [
0.282580,
0.303942,
0.295370,
0.284742,
0.331006,
]

y2 = [
1.175263,
1.187309,
1.103492,
1.119945,
1.185488,
]

z2 = [
0.332077,
0.331825,
0.329684,
0.350240,
0.324969,
]

y3 = [
1.367203,
1.321933,
1.461842,
1.460873,
1.467128,
]

z3 = [
0.383951,
0.383939,
0.388829,
0.388022,
0.383265,
]


y4 = [
1.735006,
1.735750,
1.735292,
1.704016,
1.724114,
]

z4 = [
0.429683,
0.426529,
0.445226,
0.425278,
0.428496,
]

 
figure, axis = plt.subplots(2, 2, figsize=(10, 8))

# For Sine Function
axis[0, 0].plot(x, y1, color='r', label='Normal')
axis[0, 0].plot(x, z1, color='g', label='Paralelizado')
axis[0, 0].set_title("KNN=3 PREV=2 SLIDE=3")

# For Cosine Function
axis[0, 1].plot(x, y2, color='r', label='Normal')
axis[0, 1].plot(x, z2, color='g', label='Paralelizado')
axis[0, 1].set_title("KNN=4 PREV=3 SLIDE=4")

# For Tangent Function
axis[1, 0].plot(x, y3, color='r', label='Normal')
axis[1, 0].plot(x, z3, color='g', label='Paralelizado')
axis[1, 0].set_title("KNN=5 PREV=4 SLIDE=5")

# For Tanh Function
axis[1, 1].plot(x, y4, color='r', label='Normal')
axis[1, 1].plot(x, z4, color='g', label='Paralelizado')
axis[1, 1].set_title("KNN=6 PREV=5 SLIDE=6")

figure.suptitle('Teste de 100.000 Observações')
# Out:
# Text(0.5, 0.98, 'Teste de 100.000 Observações')

# %%
x = [2, 5, 10, 50, 100]

y1 = [
9.126086,
9.094110,
9.093887,
9.096432,
9.116098,
]

z1 = [
2.715208,
2.755519,
2.717893,
2.859263,
2.743024,
]

y2 = [
11.864028,
11.892148,
11.870126,
11.625719,
11.885750,
]

z2 = [
3.275882,
3.455998,
3.518682,
3.536930,
3.509825,
]

y3 = [
14.588604,
14.591567,
14.569157,
14.190494,
14.403159,
]

z3 = [
4.099734,
4.110349,
4.151024,
4.027227,
4.025490,
]


y4 = [
17.352288,
17.122685,
17.199237,
16.729532,
17.329952,
]

z4 = [
4.566948,
4.558709,
4.558536,
4.653390,
4.553415,
]

 
figure, axis = plt.subplots(2, 2, figsize=(10, 8))

# For Sine Function
axis[0, 0].plot(x, y1, color='r', label='Normal')
axis[0, 0].plot(x, z1, color='g', label='Paralelizado')
axis[0, 0].set_title("KNN=3 PREV=2 SLIDE=3")

# For Cosine Function
axis[0, 1].plot(x, y2, color='r', label='Normal')
axis[0, 1].plot(x, z2, color='g', label='Paralelizado')
axis[0, 1].set_title("KNN=4 PREV=3 SLIDE=4")

# For Tangent Function
axis[1, 0].plot(x, y3, color='r', label='Normal')
axis[1, 0].plot(x, z3, color='g', label='Paralelizado')
axis[1, 0].set_title("KNN=5 PREV=4 SLIDE=5")

# For Tanh Function
axis[1, 1].plot(x, y4, color='r', label='Normal')
axis[1, 1].plot(x, z4, color='g', label='Paralelizado')
axis[1, 1].set_title("KNN=6 PREV=5 SLIDE=6")

figure.suptitle('Teste de 1.000.000 Observações')
# Out:
# Text(0.5, 0.98, 'Teste de 1.000.000 Observações')

# %%
train = "dados_xtrain.txt"
test = "dados_xtest_10.txt"

# %%
exe = "./og"

for hypers in ["3 2 3", "4 3 4", "5 4 5", "6 5 6"]:
    for thread in [2, 5, 10, 50, 100]:
        print(f"{exe} {train} {test} {hypers} {thread}")
# Out:
# ./og dados_xtrain.txt dados_xtest_10.txt 3 2 3 2
# ./og dados_xtrain.txt dados_xtest_10.txt 3 2 3 5
# ./og dados_xtrain.txt dados_xtest_10.txt 3 2 3 10
# ./og dados_xtrain.txt dados_xtest_10.txt 3 2 3 50
# ./og dados_xtrain.txt dados_xtest_10.txt 3 2 3 100
# ./og dados_xtrain.txt dados_xtest_10.txt 4 3 4 2
# ./og dados_xtrain.txt dados_xtest_10.txt 4 3 4 5
# ./og dados_xtrain.txt dados_xtest_10.txt 4 3 4 10
# ./og dados_xtrain.txt dados_xtest_10.txt 4 3 4 50
# ./og dados_xtrain.txt dados_xtest_10.txt 4 3 4 100
# ./og dados_xtrain.txt dados_xtest_10.txt 5 4 5 2
# ./og dados_xtrain.txt dados_xtest_10.txt 5 4 5 5
# ./og dados_xtrain.txt dados_xtest_10.txt 5 4 5 10
# ./og dados_xtrain.txt dados_xtest_10.txt 5 4 5 50
# ./og dados_xtrain.txt dados_xtest_10.txt 5 4 5 100
# ./og dados_xtrain.txt dados_xtest_10.txt 6 5 6 2
# ./og dados_xtrain.txt dados_xtest_10.txt 6 5 6 5
# ./og dados_xtrain.txt dados_xtest_10.txt 6 5 6 10
# ./og dados_xtrain.txt dados_xtest_10.txt 6 5 6 50
# ...
